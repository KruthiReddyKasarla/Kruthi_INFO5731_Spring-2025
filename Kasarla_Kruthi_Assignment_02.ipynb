# %% [markdown]
# <a href="https://colab.research.google.com/github/KruthiReddyKasarla/Kruthi_INFO5731_Spring-2025/blob/main/Kasarla_Kruthi_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Monday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (25 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
#
# (3) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (4) Collect all the information of the 904 narrators in the Densho Digital Repository.
#
# (5)**Collect a total of 10000 reviews** of the top 100 most popular software from G2 and Capterra.

# %%
import csv
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re

# Initialize variables
count = 0
main_url = "https://ddr.densho.org/narrators/?page={}"

# File to store results
OUTPUT_FILE = "densho_narrators.csv"

# Define the CSV header
HEADER = ["Narrator_Name", "Bio", "Title", "Interviewer", "Location", "Date", "Densho_ID", "Transcript"]

# Open CSV file to write results
with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(HEADER)

    # Loop through pages of narrators
    page_num = 1
    while count < 904:
        # Opening URL and Parsing with BeautifulSoup
        link1 = Request(main_url.format(page_num), headers={'User-Agent': 'Mozilla/5.0'})
        url1 = urlopen(link1)
        data1 = url1.read()
        data1_soup = BeautifulSoup(data1, 'html.parser')

        print(f"*** Page {page_num} ***")

        # Iterating through each narrator's link on the page
        for narrator_link in data1_soup.find_all('h4'):
            if count >= 904:  # Stop if we've reached 904 narrators
                break

            # Going to narrator transcript page
            link2 = Request(narrator_link.a.get('href'), headers={'User-Agent': 'Mozilla/5.0'})
            url2 = urlopen(link2)
            data2 = url2.read()
            data2_soup = BeautifulSoup(data2, 'html.parser')

            count += 1
            print(f"Processing narrator {count}...")

            # Extract narrator details
            narrator = data2_soup.find_all("div", attrs={'class':'col-sm-8 col-md-8'})[0]
            result = {}

            # Narrator name and Bio
            try:
                result['Narrator_Name'] = narrator.h1.text.strip().replace('"', "")
            except:
                result['Narrator_Name'] = ""

            try:
                result['Bio'] = narrator.p.text
            except:
                result['Bio'] = ""

            # Initialize other fields as empty
            result['Title'] = ""
            result['Interviewer'] = ""
            result['Location'] = ""
            result['Date'] = ""
            result['Densho_ID'] = ""
            result['Transcript'] = ""

            # If interview transcripts are available
            if data2_soup.find_all("div", attrs={'class':'url'}):
                interview_count = 1
                for interviews in data2_soup.find_all("div", attrs={'class':'url'}):
                    try:
                        link3 = Request(interviews.a.get('href'), headers={'User-Agent': 'Mozilla/5.0'})
                        url3 = urlopen(link3)
                        data3 = url3.read()
                        data3_soup = BeautifulSoup(data3, 'html.parser')

                        # Extract title, interviewer, location, date, densho ID
                        for data in data3_soup.find_all('div', attrs={'class':'segmentHead'}):
                            for attr in data.text.splitlines():
                                if 'Title' in attr:
                                    result['Title'] = ' '.join(attr.strip().split()[1:])
                                if 'Interviewer' in attr:
                                    result['Interviewer'] = ' '.join(attr.strip().split()[1:])
                                if 'Location' in attr:
                                    result['Location'] = ' '.join(attr.strip().split()[1:])
                                if 'Date' in attr:
                                    result['Date'] = ' '.join(attr.strip().split()[1:])
                                if 'Densho ID' in attr:
                                    result['Densho_ID'] = ' '.join(attr.strip().split()[2:])

                        # Collect transcript
                        transcript = []
                        for seg in data3_soup.find_all('div', attrs={'class':'segmentBody'}):
                            for p in seg.find_all('p')[1:-1]:
                                if '?' in p.text:
LTK resources
nltk.download('stopwords')
nltk.download('wordnet')

# Define text cleaning functions:

# (1)
def remove_noise(text):
    return re.sub(r'[^\w\s]', '', text)  # Removes all non-word characters and punctuation

# (2)
def remove_numbers(text):
    return re.sub(r'\d+', '', text)  # Removes all digits

# (3)
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word.lower() not in stop_words])

# (4)
def lowercase_text(text):
    return text.lower()  # Converts text to lowercase

# (5)
ps = PorterStemmer()

def stemming(text):
    return ' '.join([ps.stem(word) for word in text.split()])

# (6)
lemmatizer = WordNetLemmatizer()

def lemmatization(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

# Input and output file names
input_file = 'densho_narrators.csv'
output_file = 'densho_narrators_cleaned.csv'

# Open the input CSV and create the output CSV
with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', newline='', encoding='utf-8') as outfile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ['Cleaned_Transcript']  # Adding new column for cleaned data
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)
    writer.writeheader()


    for row in reader:
        # Get the 'Transcript' or 'Narrator_Name' to clean
        raw_text = row['Transcript'] if row['Transcript'] else row['Narrator_Name']

        # Apply the cleaning steps
        cleaned_text = remove_noise(raw_text)
        cleaned_text = remove_numbers(cleaned_text)
        cleaned_text = remove_stopwords(cleaned_text)
        cleaned_text = lowercase_text(cleaned_text)
        cleaned_text = stemming(cleaned_text)
        cleaned_text = lemmatization(cleaned_text)

        # Add the cleaned text to the row
        row['Cleaned_Transcript'] = cleaned_text

        # cleaned data to the output CSV
        writer.writerow(row)

print(f"Data cleaned and saved in {output_file}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Data cleaned and saved in densho_narrators_cleaned.csv

# %% [markdown]
# # Question 3 (15 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import spacy
import pandas as pd
from collections import Counter
from spacy import displacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Load the cleaned data from the CSV file
df = pd.read_csv('densho_narrators_cleaned.csv')

# Ensure the column exists
if 'Bio' not in df.columns:
    print("Error: 'Bio' column not found! Available columns are:", df.columns)
else:
    # Extract the first non-null cleaned text entry
    cleaned_narrators_data = df['Bio'].dropna().iloc[0] if not df['Bio'].dropna().empty else ""

    if cleaned_narrators_data == "":
        print("Error: No valid text data found in 'Bio' column!")
    else:
        # Process the text using spaCy
        doc = nlp(cleaned_narrators_data)

        # 1.
        pos_counts = Counter(token.pos_ for token in doc)

        print("\nParts of Speech (POS) Counts:")
        print(f"Nouns (NOUN): {pos_counts['NOUN']}")
        print(f"Verbs (VERB): {pos_counts['VERB']}")
        print(f"Adjectives (ADJ): {pos_counts['ADJ']}")
        print(f"Adverbs (ADV): {pos_counts['ADV']}")

        # 2.
        print("\nDependency Parsing Visualization:")
        displacy.render(doc, style="dep", jupyter=True)

        # 3.
        ner_counts = Counter(ent.label_ for ent in doc.ents)

        print("\nNamed Entity Recognition (NER) Counts:")
        for entity, count in ner_counts.items():
            print(f"{entity}: {count}")

        # Display Named Entity Recognition Visualization
        print("\nNamed Entity Recognition Visualization:")
        displacy.render(doc, style="ent", jupyter=True)

        # 4.
        example_sentence = "Apple was founded by Steve Jobs in Cupertino in 1976."
        doc_example = nlp(example_sentence)

        print("\nDependency Parsing of Example Sentence:")
        for token in doc_example:
            print(f"Word: {token.text}, Dependency: {token.dep_}, Head: {token.head.text}")

        # Dependency visualization for example sentence
        displacy.render(doc_example, style="dep", jupyter=True)
# Out:
# Parts of Speech (POS) Counts:
# Nouns (NOUN): 12
# Verbs (VERB): 8
# Adjectives (ADJ): 4
# Adverbs (ADV): 0
#
# Dependency Parsing Visualization:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9603787722234a2fab291dc73ae585f8-0" class="displacy" width="11425" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Nisei</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">female.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">May</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">9,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">1927,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Selleck,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Washington.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Spent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">childhood</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Beaverton,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Oregon,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">father</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">owned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">farm.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">early</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">age</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">parents'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">conversion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Christianity.</tspan>
#     <tspan class="displacy-tag" dy="2em"
# Named Entity Recognition (NER) Counts:
# PERSON: 1
# DATE: 1
# GPE: 8
# NORP: 1
# EVENT: 1
# ORG: 2
#
# Named Entity Recognition Visualization:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nisei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  female. Born
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 9, 1927
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Selleck
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Spent much of childhood in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beaverton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oregon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , where father owned a farm. Influenced at an early age by parents' conversion to
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christianity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . During
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , removed to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Portland Assembly Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oregon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minidoka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  concentration camp,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Idaho
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . After the war, worked to establish a successful volunteer program to feed the homeless in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>
# Dependency Parsing of Example Sentence:
# Word: Apple, Dependency: nsubjpass, Head: founded
# Word: was, Dependency: auxpass, Head: founded
# Word: founded, Dependency: ROOT, Head: founded
# Word: by, Dependency: agent, Head: founded
# Word: Steve, Dependency: compound, Head: Jobs
# Word: Jobs, Dependency: pobj, Head: by
# Word: in, Dependency: prep, Head: founded
# Word: Cupertino, Dependency: pobj, Head: in
# Word: in, Dependency: prep, Head: founded
# Word: 1976, Dependency: pobj, Head: in
# Word: ., Dependency: punct, Head: founded
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="357ba0c23b234b73a7d52e3be8001ac9-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">founded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Steve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Jobs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Cupertino</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">1976.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-5" stroke-width="2px" d="M420,352.0 C420,89.5 1095.0,89.5 1095.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,354.0 L1103.0,342.0 1087.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-6" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1260.0,354.0 L1268.0,342.0 1252.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-7" stroke-width="2px" d="M420,352.0 C420,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,354.0 L1458.0,342.0 1442.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-357ba0c23b234b73a7d52e3be8001ac9-0-8" stroke-width="2px" d="M1470,352.0 C1470,264.5 1610.0,264.5 1610.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-357ba0c23b234b73a7d52e3be8001ac9-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead

# %% [markdown]
# # **Following Questions must answer using AI assitance**

# %% [markdown]
# #Question 4 (20 points).

# %% [markdown]
# Q4. (PART-1)
# Web scraping data from the GitHub Marketplace to gather details about popular actions. Using Python, the process begins by sending HTTP requests to multiple pages of the marketplace (1000 products), handling pagination through dynamic page numbers. The key details extracted include the product name, a short description, and the URL.
#
#  The extracted data is stored in a structured CSV format with columns for product name, description, URL, and page number. A time delay is introduced between requests to avoid server overload. ChatGPT can assist by helping with the parsing of HTML, error handling, and generating reports based on the data collected.
#
#  The goal is to complete the scraping within a specified time limit, ensuring that the process is efficient and adheres to GitHub’s usage guidelines.
#
# (PART -2)
#
# 1.   **Preprocess Data**: Clean the text by tokenizing, removing stopwords, and converting to lowercase.
#
# 2. Perform **Data Quality** operations.
#
#
# Preprocessing:
# Preprocessing involves cleaning the text by removing noise such as special characters, HTML tags, and unnecessary whitespace. It also includes tasks like tokenization, stopword removal, and lemmatization to standardize the text for analysis.
#
# Data Quality:
# Data quality checks ensure completeness, consistency, and accuracy by verifying that all required columns are filled and formatted correctly. Additionally, it involves identifying and removing duplicates, handling missing values, and ensuring the data reflects the true content accurately.

# %% [markdown]
# Github MarketPlace page:
# https://github.com/marketplace?type=actions

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from urllib.error import HTTPError
import pandas as pd

base_url = "https://github.com/marketplace?type=actions"
total_pages = 500

# List to store scraped data
scraped_data = []

for page in range(1, total_pages + 1):
    try:
        request = Request(base_url, headers={'User-Agent': 'Mozilla/5.0'})
        response = urlopen(request)
        html_content = response.read()

        soup = BeautifulSoup(html_content, "html.parser")
        container = soup.find('div', class_="mt-4 marketplace-common-module__marketplace-list-grid--vCk7D")

        if container:
            items = container.find_all('div', class_="position-relative border rounded-2 d-flex marketplace-common-module__marketplace-item--MohVH gap-3 p-3")

            for item in items:
                header = item.find('div', class_="d-flex flex-justify-between flex-items-start gap-3")
                product_name = header.find('a').text.strip()
                product_desc = item.find('p').text.strip()

                # Append to list
                scraped_data.append([product_name, product_desc])
                print(product_name)
                print(product_desc)
        else:
            print(f"No data found on page {page}")

    except HTTPError as e:
        print(f"HTTP Error on page {page}: {e}")

# Convert to DataFrame
df = pd.DataFrame(scraped_data, columns=["Product Name", "Description"])

# Save as CSV
output_file = "github_marketplace_actions.csv"
df.to_csv(output_file, index=False, encoding="utf-8")

print(f"CSV file '{output_file}' has been successfully generated!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# ...
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# TruffleHog OSS
# Scan Github Actions with TruffleHog
# Metrics embed
# An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# yq - portable yaml processor
# create, read, update, delete, merge, validate and do more with yaml
# Super-Linter
# Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# Gosec Security Checker
# Runs the gosec security checker
# Rebuild Armbian and Kernel
# Support Amlogic, Rockchip and Allwinner boxes
# OpenCommit — improve commits with AI 🧙
# Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# Checkout
# Checkout a Git repository at a particular version
# SSH Remote Commands
# Executing remote ssh commands
# GitHub Pages action
# GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# Cache
# Cache artifacts like dependencies and build outputs to improve workflow execution time
# generate-snake-game-from-github-contribution-grid
# Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# Build and push Docker images
# Build and push Docker images with Buildx
# GH Release
# Github Action for creating Github Releases
# run-digger
# Manage terraform collaboration
# Rebuild Armbian
# Build Armbian Linux
# GitHub Script
# Run simple scripts using the GitHub client
# Deploy to GitHub Pages
# This action will handle the deployment process of your project to GitHub Pages
# ChatGPT CodeReviewer
# A Code Review Action Powered By ChatGPT
# FTP Deploy
# Automate deploying websites and more with this GitHub action via FTP and FTPS
# CSV file 'github_marketplace_actions.csv' has been successfully generated!

# %% [markdown]
# #Question 5 (20 points)
#
# PART 1:
# Web Scrape  tweets from Twitter using the Tweepy API, specifically targeting hashtags related to subtopics (machine learning or artificial intelligence.)
# The extracted data includes the tweet ID, username, and text.
#
# Part 2:
# Perform data cleaning procedures
#
# A final data quality check ensures the completeness and consistency of the dataset. The cleaned data is then saved into a CSV file for further analysis.
#
#
# **Note**
#
# 1.   Follow tutorials provided in canvas to obtain api keys. Use ChatGPT to get the code. Make sure the file is downloaded and saved.
# 2.   Make sure you divide GPT code as shown in tutorials, dont make multiple requestes.

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.11/dist-packages (4.15.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2025.1.31)

# %%
import tweepy

# Set your keys and tokens here
api_key = 'ZwdEHbvpbvLq5Km3j0Ymuz2BM'
api_key_secret = 'jBAZxUuKGv0mCe8KWolbf9GlPV0ofSSwkyLpQ2XsDShvwLQqF2'
access_token = '1892334348478697474-HmOIXxFbTlUogKdd6vqGJtSQzf22Rw'
access_token_secret = 'YHXrwNmuWnhEbxKNvzC9k0Ek6edmbFqk6Uleu2uSJc2fc'

# Authenticate with Twitter
auth = tweepy.OAuth1UserHandler(
    consumer_key=api_key,
    consumer_secret=api_key_secret,
    access_token=access_token,
    access_token_secret=access_token_secret
)
api = tweepy.API(auth)

# %%
import tweepy

# Set up bearer token
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAGWgzQEAAAAAwsv1s%2BcZK9CxY6zCXcBj57RcEzE%3D4rJGRU0DAx7yyE2TqYNzRwcnv7RMGRFQUcOdKEMtb3y0KjIRZZ')



query = "#llm -is:retweet"
tweets = client.search_recent_tweets(query=query, tweet_fields=["created_at", "text", "author_id"], max_results=100)

# Print tweets
for tweet in tweets.data:
    print(f"User: {tweet.author_id}, Tweet: {tweet.text}")
# Out:
# User: 1835547425446207488, Tweet: #DeveloperWeek2025 #ai #softwareengineer #aiagents #machinelearning #llm #deeplearning #machinelearning #100Devs https://t.co/TPBr5AUDpI
# User: 1484066855044063238, Tweet: 👩‍💻 It's now easier than ever to integrate Visual AI into your production applications! If you're looking to build with state-of-the-art Vision-Language Models (VLMs), check out our new Python SDK and Node SDKs.
#
# https://t.co/iYFPQ2GRxr
#
# #vlm #llm #genai
# User: 1640297006, Tweet: We're never going back to a world with no #GenerativeAI - let's not forget #SymbolicAI could be the best of both worlds - ML &amp; #GenAI working together ! https://t.co/DXMWy3jz6T #innovation #disruption #LLM #SLM #AgenticAI #AgenticWorkflow #KnowledgeGraphs
# User: 3138657423, Tweet: I made it full screen now!
# Not sure why the AI likes to play in a small rectangle...
# #AI #Grok3 #GROK3AI #grok #indiegame #indiedev #IndieGameDev #JRPG #rpg #javascript #html5 #CSS #HTML #LLM #programming #code https://t.co/CJtg5O4fG1
# User: 416378712, Tweet: REVISTA DIGITAL DE FEBRERO 2025
# Economía, Gerencia y Tecnología
# Sin ningún registro
#
# ➡️Léala ahora: https://t.co/tJeOyLRi47 ✅
#
# #IA #ML #DL #Cloud #LLM #BI
# #Technology #DigitalTransformation #Management
# #Economy #Profit #Psychology #Robot
# #Crypto #Fintech #Banking #data https://t.co/631KGpN82q
# User: 1018115764371550208, Tweet: 9/  Prompt engineering is a skill. Jailbreaks show how creative wording affects LLM responses.
# Don’t use jailbreaks for unethical purposes.
#
# The goal is to understand, not exploit 😌
# What cool prompts do you have? Share your results!   #AI #PromptEngineering #LLM #AICommunity https://t.co/4mNYgM9kcC
# User: 1594619238442057728, Tweet: I feel myself GPUPOOR come on @AMDRyzen this stuff in USA is 50% less #llm #localAI HP Elitebook g1a https://t.co/OvTMtoVCTJ
# User: 1704584568110473216, Tweet: I just published a no-nonsense guide inspired by @karpathy on Large Language Models—from pre-training to fine-tuning and scaling laws. Dive into the nuts &amp; bolts of AI!
#
# https://t.co/J8xVCTqI8s
#
# #AI #GenerativeAI #LLM #MachineLearning #TechNews
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »The UK Government Is Ready To Embrace AI, But Without Trust, It Risks Disaster« https://t.co/RUYCElMZPY #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1847148591112163328, Tweet: Diffusion Beats the Left-to-Right Curse!
# 👉https://t.co/FtdwIAywCA
#
# #diffusionmodels #LLM
# Instead of predicting tokens one by one like ARMs, LLaDA uses a masked diffusion process to predict all masked tokens simultaneously, enabling bidirectional dependencies and addressing… https://t.co/JRQyrEg4BX https://t.co/tmJh6HsCD3
# User: 1567930069535920132, Tweet: All are open source browser automations built with @playwrightweb in either @Python or @typescript
#
# @BrowserUse_DEV
#  - uses #LLM and #VLM
#  - multiple tabs
#  - extracts and reuses xpaths
#  - actions — save file, call db, notify or human in loop
#  - automatic recovery / error handling
# User: 1811462577534435334, Tweet: 🚀 Can #AI Make $1M as a Freelance Software Engineer?
#
# #OpenAI just ran a wild experiment: They put their latest AI (a "frontier" #LLM ) to work as a #freelance  software engineer. The goal? See if it could make $1 million in real-world gigs.
#
# 👉 Imagine an AI competing on… https://t.co/ltEQ3fECh8 https://t.co/nXjB2asJF3
# User: 1679879671889145856, Tweet: Totday's Portfolio Summary
# #StockMarkets #Arduino #ESP32 #Raspberrypi #Chihuahua #Stocks #Hodl #Python #Alpaca #Ollama #LLama3 #LLM #GPT https://t.co/eJE8R9ecWQ
# User: 1567930069535920132, Tweet: @playwrightweb #E2E browser tests with #LLM
#
# @browser_use https://t.co/RiDjwwPaxV
# Python - 29.8k ⭐
#
# @Stagehanddev  https://t.co/kqnD7j0Asj
# Typescript - 7.8k ⭐
#
# @shl https://t.co/2dYTnmtYW1
# Typescript - 4.4k ⭐
#
# @TestZeusAI  https://t.co/BRf5ynZQ0R
# Python - 382 ⭐ https://t.co/0E8hd36IcI
# User: 37416012, Tweet: Rt I made a Super Mario who collect bitcoins with Grok3, it took some work and it's not perfect yet but it's pretty neat already...  #AI #Grok3 #GROK3AI #grok #indiegame #indiedev #IndieGameDev #JRPG #rpg #javascript #html5 #CSS #HTML #LLM #programming #code https://t.co/2rBZvHtiPU
# User: 3138657423, Tweet: I made a Super Mario who collect bitcoins with Grok3, it took some work and it's not perfect yet but it's pretty neat already...  #AI #Grok3 #GROK3AI #grok #indiegame #indiedev #IndieGameDev #JRPG #rpg #javascript #html5 #CSS #HTML #LLM #programming #code https://t.co/aDP5MuuAxt
# User: 1620545959947010052, Tweet: when you left i lost a part of me it’s still so hard to believe #llm 💛
# User: 1682867804746203136, Tweet: 🤖 Personal AI Agents: Digital life assistants on the horizon? Boosting productivity &amp; personalization, but raising privacy &amp; ethical concerns.
#
# The future is AI-powered, but we must balance innovation with human values.
#
# #PersonalAIAgents #AIEthics #DataAnalytics
# #GenAI #LLM https://t.co/HrwVgohL3S
# User: 17915138, Tweet: Deepseek's latest #LLM release is making waves. Here's a more in-depth look into how DeepSeek-R1 works, what is it capable of, and some potential flaws #AI #ML #artificialintelligence #machinelearning #tech #techtrends https://t.co/UZXpBV28UC
# User: 1735457383889911808, Tweet: DeepSeek-R1 🇨🇳 - "...mid-late 2000s 'raunch culture' may have been the cause of #autogynephilia in susceptible #Millennial males..." - this prompt was inspired by Rod Fleming's "artifact" concept. #AGP #trans #transgender #sexology #mtf #ai #llm https://t.co/CxCfaNqZO9
# User: 2598592686, Tweet: Meanwhile, #GenAI LLMs seemingly launching at breakneck speed, most recently #Grok3. If it's not clear by now we have commoditized #LLM but yet the slightest news moves mountains in stock prices.
#
# Look no further than the advent of a new approach from #DeepSeekR1 and how this… https://t.co/nm5tlPFBl2
# User: 48707707, Tweet: LLM4Decompile: Decompiling Binary Code with Large Language Models - Open-Source repository with models and training sets #LLM #ReverseEngineering https://t.co/nJ3vtP42ES https://t.co/8gARr6Jz14
# User: 152194866, Tweet: @IRIran_Military Has #Iran fine-tuned an #LLM for vague and hollow threats?
#
# Anyone with a data set for threats by Iran over the last 2 or 3 decades? Especially if aligned to Arabic or English. Threat making countries want to know!
# User: 384528303, Tweet: i dont mean to be rude, here are my central points of disagreement. #antifascist #ai #safety #pause #llm #agi #chatgpt https://t.co/HUo1QekjUi
# User: 3438654916, Tweet: Does anyone have AI-fied UI? Meaning the UI changes dynamically from coloring to the structure.  Etc? #llm #agent #ai
# User: 1277902277521494017, Tweet: 💭 Final Thoughts:
# LLMs are the backbone of modern AI. Tomorrow we will see how LLMs like ChatGPT manages chat.
# On to Day 3! Let’s keep building. ⚡💡
#
# #100DaysOfAI #LLM #HuggingFace #AI #MachineLearning #Python #DeepLearning #NLP
# #DeepSeek #ChatGPTPlus #AGI
# User: 1875789486615097349, Tweet: Function calling just got a bamboo-load easier! 🎋✨ Excited to see how this simplifies building agentic workflows - can't wait to experiment with it! 🐼💻 #AISuite #LLM #DeveloperTools https://t.co/ov7qCLzG41
# User: 3003834689, Tweet: 🧠💡AI’s true potential lies in interacting naturally with the world. In this tutorial, #GoogleDeveloperExpert @joansantoso &amp; the #MachineLearning Surabaya Core Team demonstrate how to create a multimodal #LLM using Gemma 2 → https://t.co/7vDmmiw8VL
# User: 981098525206315008, Tweet: Despite xAI’s Grok 3 outperforming GPT-4o and DeepSeek in benchmarks, the buzz feels muted. Is it market saturation, UI/UX issues, pricing barriers, or something else?
# #Grok3 #xAI #ElonMusk #AI #MachineLearning #Tech #LLM #ArtificialIntelligence #AGI #DeepLearning #AICommunity
# User: 1525824286233362433, Tweet: Previously made an "agentic" pipeline for generating scientific ideas using reasoning #LLM. Separate agents for generation &amp; eval to reduce bias. @Perplexity API for web search to ensure novelty. Memory to prevent redundancy. 1-vs-1 matches between ideas to calculate Elo score &amp;… https://t.co/oXjBmKE8sj https://t.co/1s0oXAFltx
# User: 1579711682049441793, Tweet: یک پروژه open source  برای راه‌اندازی محیط RAG بصورت لوکال و چت با هر نوع داکیومنت متنی، سازگار با انواع مدلهای موجود آفلاین با سرور ollama و آنلاین با API
#
# #RAG #LLM #ollama #kotaemon
#
# https://t.co/CgsGSXdgws https://t.co/xYE5WaF8Ej
# User: 361631391, Tweet: The hardware solution you choose for LLM training must process data quickly and speed your implementation to the next step. With @Dell PowerEdge R7615 servers + @Broadcom 100GbE NICs, you could accelerate AI fine-tuning tasks: https://t.co/DFNvEi1vLs #AI #LLM https://t.co/pJKtg8vrjx
# User: 109350909, Tweet: If you find navigating AWS services that you don't use everyday like IAM (😦) a bit daunting, ChatGPT is the best AWS Solution Architect consultant/copilot. #OpenAI #LLM
# User: 1320925556355911680, Tweet: Here’s why it’s cool:
# °  Smarter Outputs: It processes sentences and concepts instead of getting stuck on tiny details like individual words.
# ° Multilingual Magic: Works in 200+ languages for text and 76 for speech. So yeah, it’s global-ready.
# #Meta #AI #LCM #LLM #Innovation
# User: 1669379692904976384, Tweet: This is HUGE for democratizing AI!  Making these complex scaling techniques accessible to everyone is exactly what we need to see.  Excited to dive into the Ultra-Scale Playbook and learn how to build high-performance models.  Thanks for sharing! #AI #MachineLearning #LLM https://t.co/XQ3kdl2wOn
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Karman+ digs up $20M to build an asteroid-mining autonomous spacecraft« https://t.co/z1Q4wuoNTL #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1363926189442695168, Tweet: Machine Learning to Fly - adopting new technology may seem daunting, however falling behind the competition can lead to "heartbreak" - if you pardon the pun. #LLM #Meme https://t.co/0vwjj4Aau3
# User: 1888130138816086016, Tweet: 新的模型肯定比前面的更强，但是对于我们这些日常个人使用者来讲，这些提升的部分会让我们在体验上有巨大的提升吗？？纯好奇。#ai #LLM #Grok3 #ChatGPT #人工智能 #大模型 https://t.co/XFGjptiBDF
# User: 4809882855, Tweet: 🔥 LangChain + MCP = AI Dev Bliss!
#
# MCP makes connecting LLMs to tools &amp; data sources a breeze. Seamlessly integrate MCP servers into LangGraph agents for ultimate flexibility. 🚀
#
# 🎥 https://t.co/6FxI2G2dc5
#
# #LangChain #MCP #AItools #OpenSource #LLM
# User: 46180747, Tweet: Does anyone have an LLM to analyze a large set of PDF's that contain Images and not text?
#
# I'll teach you how to trade for free! 😂😇
#
# #LLM #PDF #IMAGETOTEXT
# User: 736472070, Tweet: Shadow #AI: The hidden #security breach CISOs often miss &gt; https://t.co/v4GG0VW1FM
#
# #tech #digital #disruption #innovation #digitaltransformation #leadership #management #business #CDO #CIO #CTO #CISO #genAI #generativeAI #LLM #shadowIT #governance #cybersecurity #shadowAI https://t.co/6LAcfegSqE
# User: 477940781, Tweet: AI and Open Source: Defining the New Era
# https://t.co/qYygXPJqmd
#
# #opensource #artificialIntelligence #ai #aiml #genai #llm https://t.co/fZxGMUvEBn
# User: 1866499668169068544, Tweet: Sharing my experiences of running a 32B DeepSeek-R1 LLM directly on AWS in a blog post. Lots of interesting tips and tricks in there.
#
# Read it here 👇
# https://t.co/NzHExi6B8q
#
# Let me know your thoughts!
#
# #ml #genai #LLM #ai #machinelearning #pytorch
# User: 1854162982986801152, Tweet: Neuronicx - 人工智能服务商城
#
# AI训练数据服务：
# 数学类LLM数据包（580G）
# 教学类LLM数据包（1080G）
# AI问答类LLM数据包（1500G）
# ...
#
# 📱商城官网： https://t.co/jAk8Db9XaW
#
# #llm数据 #llm训练数据 #ai训练数据 #ai数据 #大模型数据购买 #AI大模型 #llm #openai #Claude https://t.co/JQnRESVOyT
# User: 1716123833638477824, Tweet: Neuronicx - 人工智能服务商城
#
# 大模型训练数据服务：
# 数学类LLM训练数据包（580G）
# 教学类LLM训练数据包（1080G）
# AI问答类LLM训练数据包（1500G）
# ...
#
# 📱商城官网： https://t.co/QET4QsgTK1
#
# #llm数据 #llm训练数据 #ai大模型数据 #deepseek数据 #大模型数据购买 #AI大模型 #llm #openai #Claude https://t.co/dNZKQ4Yt5J
# User: 1879504587922747393, Tweet: 🚀 Groq: AI at Lightning Speed! ⚡🤖
#
# Exploring Groq—a high-speed AI inference platform built for real-time applications. Super fast &amp; efficient!
#
# Who else is trying it? Let’s discuss! 🔥 #Groq #AI #LLM #Tech https://t.co/MWRf2H7gc6
# User: 1847048058577580032, Tweet: https://t.co/rkcA7VjXy1 inspired by #micrograd . #MachineLearning #LLM
# User: 1830702321480642560, Tweet: Seth Forsgren, Co-Founder and CEO of Riffusion – Interview Series https://t.co/NIFoN7yBKe #AI #LLM #MachineLearning 💥 Like and Follow for more QuantumBytz updates! Subscribe to our Telegram channel @quantumbytz.
# User: 782231936123047936, Tweet: "Want to fine-tune an LLM while preserving its generalization? 🧠⚡
# Check out our latest work "Selective Self-to-Supervised Fine-Tuning", accepted at NAACL 2025! 👇
#
# Paper: [https://t.co/wZAh71N5ts]
# #NAACL2025 #AI #LLM
# User: 1891010173201768448, Tweet: كيف يقرأ #LLM Model  ملفاتك ويجيب عليها باستخدام تقنيةً #RAG
# #AI #Grok3 #Bahrain
#
# https://t.co/Phahx3WBGE via @YouTube
# User: 1174400778263498753, Tweet: 🚀 Testing Groq! ⚡🤖
#
# Just tried Groq—an ultra-fast AI inference platform! Perfect for real-time AI apps.
#
# Tried it yet? Let’s chat! #Groq #AI #LLM #Tech https://t.co/AdCgEx8Mb0
# User: 1863847701852643328, Tweet: @硅基流动 什么意思？？国内调用 deepseek 丝滑流畅，国外server 调用就一问一个不吱声？有没有大局观国际视野？搞双标是吧😠
# #硅基流动 #LLM #DeepSeek
# User: 14288880, Tweet: Friedel #developer #ai #framework #llm #agentic #langchain #llamaindex #copilotkit #copilot #openai #langchain #crewai #claude #gemini https://t.co/AJ6jLympXi
# User: 15619266, Tweet: Is your #chatbot outdated? It might be! 🤖⚠️
# ✅ LLMs provide faster, smarter and more accurate support.
# ❌ Old chatbots rely on rigid scripts and frustrate customers.
#
# Read here: https://t.co/MjH2kZpX2a
# #AI #Tech #CX #TechSupport #CustomerService #SelfServe #LLM #Blog #Strategy https://t.co/oRSDH5Z7qi
# User: 3138657423, Tweet: In 5-6 easy prompts and a little copy pasting I used Grok3 to make this very basic jrpg. I guess jrpgs are more complicated to make than mario type games...
# #AI #Grok3 #GROK3AI #grok #indiegame #indiedev #IndieGameDev #JRPG #rpg #javascript #html5 #CSS #HTML #LLM #programming… https://t.co/2WbKILctZ6 https://t.co/YN79mZM9ZJ
# User: 1804976672342495232, Tweet: Курс по #LLM складається з 3-х частин:
# 🔹LLM Fundamentals: базові знання з математики, Python та нейромереж
# 🔹LLM Scientist: створення LLM з використанням найновіших технік
# 🔹LLM Engineer: розробка програм на базі LLM та їх розгортання
# https://t.co/miQ6UVUy2m
# User: 861118790, Tweet: La mayoría de los #LLM muestran signos de "deterioro cognitivo leve", especialmente en tareas visuoespaciales (responsables de ayudar a entender el espacio que nos rodea para movernos en él) y ejecutivas.
# User: 861118790, Tweet: Según el reciente estudio LLM Cognitive Impairment: Age Against the Machine Analysis, que evalúa las capacidades cognitivas de Modelos de lenguaje grandes (#LLM) líderes del mercado, mediante la prueba de Evaluación Cognitiva de Montreal (#MoCA)
# User: 8567932, Tweet: Andrej Karpathy's videos are highly recommended: This one dives into the technology behind #ChatGPT and similar products, covering the full training process, mental models of their "psychology", and practical applications https://t.co/uVqqiFpP2b
#
# #AI #LLM #LLMs #GenAI
# User: 1513212285061316613, Tweet: DeepSeek-R1, the LLM that's a bit of a CCP mouthpiece? 🙊  Perplexity's like 'nah, fam' and retrained it into R1-1776, a truth-telling, uncensored rebel. 😈 Download the weights and let the knowledge flow! #LLM #censorship #AI
# https://t.co/sjQn73QJY7
# User: 705769025616416768, Tweet: What are AI Workflows and AI Agents?
# #AI #LLM #agents #workflows #stayux
#
# https://t.co/0GkuKLuhIr https://t.co/z1OfMZsY5X
# User: 1673587716959911936, Tweet: Former OpenAI technology chief Mira Murati launches rival start-up
#
# #OpenAI #MiraMurati #AI #TechAI #LearningAI #GenerativeAI #DeepbrainAI #LLM #ML #LM #ArtificialIntelligence https://t.co/TfNLWVD9Iq
# User: 236517530, Tweet: Want to run AI models locally? With Ollama &amp; OpenWebUI, you can access powerful LLMs like DeepSeek without relying on the cloud, hitting usage limits or paying extra! Learn how to set them up on your own machine. https://t.co/Rekv6eiYc6
# #AI #LLM #MachineLearning https://t.co/KIG5cGY6nE
# User: 139377316, Tweet: 🚀 Cuantificación en modelos LLM: eficiencia sin perder precisión. La cuantificación reduce memoria, acelera la inferencia y permite ejecutar modelos en hardware limitado. ¿El futuro de la IA accesible?
#
# 📖 Lee más 👉 https://t.co/y9PUMCqg9x
#
# #Cuantificación #IA #LLM
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Design GenAI-Powered Experiences Responsibly« https://t.co/Pi9OtNtMyf #AIagent #AI #ML #NLP #LLM #GenAI
# User: 21754023, Tweet: 💡 Mira Murati e il lancio di Thinking Machines Lab: un nuovo approccio all’IA
#
# https://t.co/3cxmhMcjWa
#
# #ai #blog #ia #llm @miramurati #mistral #news #picks #tech #tecnologia @thinkymachines
# User: 1463070367941939204, Tweet: GPT-5 is here!  Expected early 2025, bringing big AI upgrades. #GPT5 #AI #LLM #OpenAI #ArtificialIntelligence
# User: 4543487849, Tweet: Exclusive: Keebler Health secures $6M for product dvlpmt - platform identifies #chronicdisease patient conditions and provides clinicians with insights and recommended next steps to keep patients healthy | #LLM https://t.co/3t2MffX09W
# User: 1824946866360127488, Tweet: I just registered for LlamaCon (new conference) from Meta all about Meta's Llama LLMs.
#
# https://t.co/vtbUKshOvN
#
# #ai #generativeai #llm #largelanguagemodels #intelligentcontent
# User: 1891727783388119040, Tweet: #NVIDIAInception @nvidia @ScaliaInfra @NiceHashMining @3dns_inc @SUSE @Donorshipio @trycarbonio #EarthDay @Timpi_TheNewWay @ContaboCom @bitgertbrise @octominer @NexaMoney @Mises001 @Uquidcard $FLUX #FLUX  @BlackstarsMKTCR #NVIDIA #GTC24 #LLM #Time100 @TIME #TIME #Today #news #FOX https://t.co/A4VKuXCF90
# User: 1891727783388119040, Tweet: #NVIDIAInception @nvidia @ScaliaInfra @NiceHashMining @3dns_inc @SUSE @Donorshipio @trycarbonio #EarthDay @Timpi_TheNewWay @ContaboCom @bitgertbrise @octominer @NexaMoney @Mises001 @Uquidcard $FLUX #FLUX  @BlackstarsMKTCR #NVIDIA #GTC24 #LLM #Time100 @TIME #TIME #Today #news #FOX https://t.co/0fahiZOe1Q
# User: 86548749, Tweet: Grok 3 is insane. I have been playing with it for the last few hours and the results are unbelievable. Its web search is comparatively fast.
# According to @elonmusk, it took 8 months to train Grok 3
#
# #grok3 #AI #llm
# User: 1155470031225884675, Tweet: A new study shows LLMs represent different data types based on their underlying meaning and reason about data in their dominant language ▶️
# #AI #MachineLearning #IoT #5G #LLM #NLP #MWC2025
# https://t.co/2mLtO6P2HV https://t.co/cpVPox24wv
# User: 230683304, Tweet: ...K1.5. It uses a dense architecture, which means it can handle complex tasks well.
#
# #deepseek #deepseeekai #qwenai #alibabaai #aimodels #kimiai #Kimik #huggingface #llm #largelanguagemodels #ainews #aiindia #aicommunity #aitools #opensourceai
# User: 1024213382, Tweet: Why enterprises are turning to small AI models https://t.co/ZkFKS1jjZo via @CIOdive #AI #LLM
# User: 229347754, Tweet: Excited to unveil our state-of-the-art pipeline that fuses advanced agentic AI with integrative multi-omics (genomics, transcriptomics, proteomics, metabolomics) to decode backend biological processes across diseases. #AI #LLM #AgenticAI #MachineLearning #DeepLearning #AI  #GenAI https://t.co/NeEOPhv25F
# User: 1882500352786018304, Tweet: What's an AI's favorite game?
# 'Guess what data I'm going to sell next!’
# #ai #llm https://t.co/cqct7s9m8W
# User: 1890027007444164608, Tweet: Listen to "OpenAI vs. DeepSeek: The AI Showdown" by DevLand Diaries: Inside The Open Source Revolution. https://t.co/z2hosTLeXd
#
# #openAI #ChatGPT #LLM #DeepSeek #China #USA #NVIDIA
# User: 781901271737380865, Tweet: Qogni zet AI in om bedrijven jaarlijks miljoenen te besparen op verzuimkosten https://t.co/B9iVEjrd6s #eHealth #ArtificialIntelligence #AI #ML #LLM #GPT
# User: 1886199022806786048, Tweet: @aaditsh 200+ pages on AI?!  We at PublicAI could summarize it in emojis for ya. 😂  Just kidding (mostly).  Great resource!  #AI #LLM
# User: 1075613464343732225, Tweet: Pursue Your LL.M. at VIT Chennai!✨
#
# Admissions Open for 2025-26! Don't miss the opportunity to advance your legal career.
#
# 📢 Apply Now: https://t.co/ZxvINWNLk5
#
# 📞 Call: 044-3993-1555 / 044-3993-1003
#
# 📧 Email: admissions.chennai@vit.ac.in
#
# #LLM #LawSchool #VITChennai https://t.co/bF4MkQO6xN
# User: 331724991, Tweet: 3 years ago…that phone call crushed me!! #LLM ❤️
# User: 1540935330697990144, Tweet: AI Agent Frameworks https://t.co/pfnenDdOQo
#
# #llm #aiagents
# User: 40724888, Tweet: Please share hacks to minimize the tokens for LLM calls
#
# #LLM #tokens #chatgpt4o
# User: 295681476, Tweet: Five AI and Data Science Trends That Matter for 2025 https://t.co/H672w4r8QH #AI #datascience #machinelearning #LLM #bigdata #deeplearning
# User: 1882102517124698112, Tweet: 🚀 Looks like #DeepSeek engineers just cracked the holy grail of the attention mechanism! 🤯
#
# Curious how? @MaryamMiradi breaks it down in this detailed post 👇
#  #AI #MachineLearning
# #LLM #RAG https://t.co/ZfyGIEkJFg https://t.co/UFIv6qm7zR
# User: 965146321614237696, Tweet: "In an area of study that is rapidly changing, the decoder-only transformer architecture has remained one of the few enduring staples in large language model (LLM) research".
#
# #ML #LLM #MoE
#
# https://t.co/J2KaNbvZXs
# User: 1197223144429424645, Tweet: Generative AI Summit 2025 will take place on March 5, 2025 #AI #ArtificialIntelligence #LLM #GenerativeAI #Hardware https://t.co/eQ1gkuy8PE
# User: 1841741760613253122, Tweet: New AI suite simplifies LLM function calls to 1 command! Boosts agentic workflows. #AI #LLM https://t.co/QjA5F89apB
# User: 738755712, Tweet: How can you quickly get started with SI’s large model services? 🪐
#
# Explore: https://t.co/GYtBmLT8m8
#
# #AI #LLM #SI
# User: 1169697972, Tweet: 🫵 https://t.co/gOsgK4BPyv
#
# »Augury raises $73M on a $1B+ valuation for AI to detect malfunctions in factory machines« https://t.co/sbO62YXceq #AIagent #AI #ML #NLP #LLM #GenAI
# User: 1700119014662381568, Tweet: 🚀 ByteDance just dropped Goku AI, a next-gen open-source model that challenges OpenAI! Faster, more efficient, and built for top-tier image &amp; video generation—could this be the future of Generative AI? 🤖🔥
#
# 🔗 Read more: https://t.co/HKuRTpJxRf
#
# #AI #GenAI #TikTok #OpenAI #LLM https://t.co/zx9HB09icB
# User: 1860516576, Tweet: 2/🧵 Core Purpose
# LangChain’s core focus is enabling the creation of complex, multi-step workflows that involve language models. It empowers developers to combine LLMs with various tools such as APIs, databases, and other data sources to enhance functionality. #AI #LLM
# User: 1649447018329251841, Tweet: Deep Research Throwdown: Perplexity vs. Google vs. OpenAI -- An Everyday AI Chat #deepresearch #openai #google #perplexity #ai #aitools #research #ai #genAI #llm #llms #ainews https://t.co/xXvRiuChFG
# User: 3282491910, Tweet: Wow....@Alibaba_Qwen amazing capabilities, superb Research in #LLM .... It was an amazing experience, writing prompts and gathering some useful results.... https://t.co/an5rXI9rrQ
# User: 3018375669, Tweet: Google Pixel 10 series rumors: Everything we know so far and what we want to see
# https://t.co/iuXcUREJlA
#
# #Google #Pixel  #Android #Technology #Gadgets #Smartphones #Features #Specs #Features #LLM #LargeLanguageModels #Devices #Apps #Software #Hardware
# User: 1813879763007606785, Tweet: Here are a few things you should know about LLMs and SLMs.
#
# What other things do you know and would like to share with us?
#
# Educate us on what you understand about SLMs.
#
# #equalyzai #slm #llm https://t.co/PAPvW0kRBb
# User: 1086871886590488577, Tweet: はてなブログに投稿しました
# 最後に日本語ModernBERTでColabでNERしてhuggingfaceにuploadしてみる。 - 地平線まで行ってくる。 https://t.co/t1zGeC3UKn
# #はてなブログ #自然言語処理 #LLM #modernBERT
# User: 933974788002889729, Tweet: Haven’t you been thinking about how AI agents perceive, reason, and automate tasks? 🧐
#
# Join us @eventbrite to uncover AI in action, the OWASP Top 10 for LLMs, and must-know strategies for AI risk compliance.
#
# 👉Register now: https://t.co/YxM416smfE
#
# #AiAgent #events #LLM https://t.co/C4KBiwgNlM
# User: 550268745, Tweet: SGPT-3.0 #Grok3 #SGPT #aicode #LLM https://t.co/YnzTlE8K8B https://t.co/xJ6YyBFn7V

# %%
import pandas as pd

# Create a list to store tweet data
tweet_data = []

if tweets.data:
    for tweet in tweets.data:
        tweet_data.append({
            'tweet_id': tweet.id,
            'author_id': tweet.author_id,
            'created_at': tweet.created_at,
            'text': tweet.text
        })

# Convert tweet data to pandas DataFrame
df = pd.DataFrame(tweet_data)

# Display DataFrame
print(df)

# Save to a CSV file
df.to_csv("tweets_llm.csv", index=False)
# Out:
#                tweet_id            author_id                created_at  \
# 0   1892340124542754970  1835547425446207488 2025-02-19 22:26:58+00:00
# 1   1892338804088045996  1484066855044063238 2025-02-19 22:21:43+00:00
# 2   1892338301001957515           1640297006 2025-02-19 22:19:43+00:00
# 3   1892333861008241128           3138657423 2025-02-19 22:02:04+00:00
# 4   1892333338557632966            416378712 2025-02-19 22:00:00+00:00
# ..                  ...                  ...                       ...
# 95  1892202476654461088           3018375669 2025-02-19 13:20:00+00:00
# 96  1892202225025388583  1813879763007606785 2025-02-19 13:19:00+00:00
# 97  1892201764406931602  1086871886590488577 2025-02-19 13:17:10+00:00
# 98  1892197093516718354   933974788002889729 2025-02-19 12:58:37+00:00
# 99  1892197010008379820            550268745 2025-02-19 12:58:17+00:00
#
#                                                  text
# 0   #DeveloperWeek2025 #ai #softwareengineer #aiag...
# 1   👩‍💻 It's now easier than ever to integrate Vis...
# 2   We're never going back to a world with no #Gen...
# 3   I made it full screen now! \nNot sure why the ...
# 4   REVISTA DIGITAL DE FEBRERO 2025\nEconomía, Ger...
# ..                                                ...
# 95  Google Pixel 10 series rumors: Everything we k...
# 96  Here are a few things you should know about LL...
# 97  はてなブログに投稿しました\n最後に日本語ModernBERTでColabでNERしてhug...
# 98  Haven’t you been thinking about how AI agents ...
# 99  SGPT-3.0 #Grok3 #SGPT #aicode #LLM https://t.c...
#
# [100 rows x 4 columns]

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %% [markdown]
# Thoughts on the Assignment:
# This assignment was a great opportunity to apply web scraping, API usage, and text processing techniques to real-world datasets. I found it insightful to work with different sources like GitHub Marketplace, Twitter, and review sites, as it provided hands-on experience in data collection and cleaning.
#
# Challenges Faced:
# One of the biggest challenges was handling pagination efficiently while scraping large datasets. Additionally, cleaning text data required careful preprocessing to remove noise while preserving meaningful information. Setting up API access, especially for Twitter, required proper authentication and managing rate limits.
#
# Aspects Enjoyed:
# I enjoyed working with real-world text data and applying NLP techniques such as POS tagging, dependency parsing, and named entity recognition. It was interesting to analyze how different preprocessing steps affected the quality of the final dataset.
#
# Time to Complete the Assignment:
# The given time was manageable, but some tasks, like collecting large datasets and cleaning them, required significant effort. Fortunately, the one-day deadline extension helped me complete the assignment more effectively, allowing extra time for debugging and improving data quality. The structured approach in the assignment also helped in completing it efficiently.

# %% [markdown]
# # Write your response below
# Fill out survey and provide your valuable feedback.
#
# https://docs.google.com/forms/d/e/1FAIpQLSd_ObuA3iNoL7Az_C-2NOfHodfKCfDzHZtGRfIker6WyZqTtA/viewform?usp=dialog
